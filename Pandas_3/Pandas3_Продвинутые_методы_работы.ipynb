# %%
import pandas as pd

# %%
melb_df = pd.read_csv('melb_data_fe.csv')
melb_df
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG        Date  \
# 0        Abbotsford      2  house  1480000.0      S    Biggin  2016-03-12
# 1        Abbotsford      2  house  1035000.0      S    Biggin  2016-04-02
# 2        Abbotsford      3  house  1465000.0     SP    Biggin  2017-04-03
# 3        Abbotsford      3  house   850000.0     PI    Biggin  2017-04-03
# 4        Abbotsford      4  house  1600000.0     VB    Nelson  2016-04-06
# ...             ...    ...    ...        ...    ...       ...         ...
# 13575         other      4  house  1245000.0      S     Barry  2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams  2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine  2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney  2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village  2017-08-26
#
#        Distance  Postcode  Bedroom  ...  Longtitude  \
# 0           2.5      3067        2  ...   144.99840
# 1           2.5      3067        2  ...   144.99340
# 2           2.5      3067        3  ...   144.99440
# 3           2.5      3067        3  ...   144.99690
# 4           2.5      3067        3  ...   144.99410
# ...         ...       ...      ...  ...         ...
# 13575      16.7      3150        4  ...   145.16761
# 13576       6.8      3016        3  ...   144.87904
# 13577       6.8      3016        3  ...   144.88738
# 13578       6.8      3016        4  ...   144.89299
# 13579       6.3      3013        4  ...   144.88449
#
#                        Regionname  Propertycount  MeanRoomsSquare AreaRatio  \
# 0           Northern Metropolitan           4019        25.200000 -0.231707
# 1           Northern Metropolitan           4019        15.800000 -0.327660
# 2           Northern Metropolitan           4019        18.750000  0.056338
# 3           Northern Metropolitan           4019        15.750000  0.145455
# 4           Northern Metropolitan           4019        17.750000  0.083969
# ...                           ...            ...              ...       ...
# 13575  South-Eastern Metropolitan           7392        12.600000 -0.676093
# 13576        Western Metropolitan           6380        16.625000 -0.429185
# 13577        Western Metropolitan           6380        15.750000 -0.551601
# 13578        Western Metropolitan           6380        17.444444 -0.693060
# 13579        Western Metropolitan           6543        12.444444 -0.527426
#
#        MonthSale  AgeBuilding WeekdaySale  StreetType  Weekend
# 0              3           46           5          St        1
# 1              4          116           5          St        1
# 2              4          117           0          St        0
# 3              4           47           0       other        0
# 4              4            2           2          St        0
# ...          ...          ...         ...         ...      ...
# 13575          8           36           5          Cr        1
# 13576          8           22           5          Dr        1
# 13577          8           20           5          St        1
# 13578          8           97           5          St        1
# 13579          8           97           5          St        1
#
# [13580 rows x 26 columns]

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  object
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  object
#  5   SellerG          13580 non-null  object
#  6   Date             13580 non-null  object
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  object
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  object
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  int64
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  int64
#  24  StreetType       13580 non-null  object
#  25  Weekend          13580 non-null  int64
# dtypes: float64(8), int64(10), object(8)
# memory usage: 2.7+ MB

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'])

# %%
melb_df['Quarter'] = melb_df['Date'].dt.quarter

# %%
melb_df
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 0        Abbotsford      2  house  1480000.0      S    Biggin 2016-03-12
# 1        Abbotsford      2  house  1035000.0      S    Biggin 2016-04-02
# 2        Abbotsford      3  house  1465000.0     SP    Biggin 2017-04-03
# 3        Abbotsford      3  house   850000.0     PI    Biggin 2017-04-03
# 4        Abbotsford      4  house  1600000.0     VB    Nelson 2016-04-06
# ...             ...    ...    ...        ...    ...       ...        ...
# 13575         other      4  house  1245000.0      S     Barry 2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams 2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine 2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney 2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village 2017-08-26
#
#        Distance  Postcode  Bedroom  ...                  Regionname  \
# 0           2.5      3067        2  ...       Northern Metropolitan
# 1           2.5      3067        2  ...       Northern Metropolitan
# 2           2.5      3067        3  ...       Northern Metropolitan
# 3           2.5      3067        3  ...       Northern Metropolitan
# 4           2.5      3067        3  ...       Northern Metropolitan
# ...         ...       ...      ...  ...                         ...
# 13575      16.7      3150        4  ...  South-Eastern Metropolitan
# 13576       6.8      3016        3  ...        Western Metropolitan
# 13577       6.8      3016        3  ...        Western Metropolitan
# 13578       6.8      3016        4  ...        Western Metropolitan
# 13579       6.3      3013        4  ...        Western Metropolitan
#
#        Propertycount  MeanRoomsSquare  AreaRatio MonthSale  AgeBuilding  \
# 0               4019        25.200000  -0.231707         3           46
# 1               4019        15.800000  -0.327660         4          116
# 2               4019        18.750000   0.056338         4          117
# 3               4019        15.750000   0.145455         4           47
# 4               4019        17.750000   0.083969         4            2
# ...              ...              ...        ...       ...          ...
# 13575           7392        12.600000  -0.676093         8           36
# 13576           6380        16.625000  -0.429185         8           22
# 13577           6380        15.750000  -0.551601         8           20
# 13578           6380        17.444444  -0.693060         8           97
# 13579           6543        12.444444  -0.527426         8           97
#
#        WeekdaySale StreetType  Weekend  Quarter
# 0                5         St        1        1
# 1                5         St        1        2
# 2                0         St        0        2
# 3                0      other        0        2
# 4                2         St        0        2
# ...            ...        ...      ...      ...
# 13575            5         Cr        1        3
# 13576            5         Dr        1        3
# 13577            5         St        1        3
# 13578            5         St        1        3
# 13579            5         St        1        3
#
# [13580 rows x 27 columns]

# %%
melb_df['Quarter'].value_counts()
# Out:
# Quarter
# 3    4873
# 2    4359
# 4    2329
# 1    2019
# Name: count, dtype: int64

# %% [markdown]
# Преобразуйте все столбцы, в которых меньше 150 уникальных значений, в тип данных category, исключив из преобразования столбцы Date, Rooms, Bedroom, Bathroom, Car.
#
# В качестве ответа запишите результирующее количество столбцов, которые имеют тип данных category.

# %%
stop = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
for col in melb_df.columns:
  if melb_df[col].nunique() < 150 and col not in stop:
    melb_df[col] = melb_df[col].astype('category')

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
#  16  Longtitude       13580 non-null  float64
#  17  Regionname       13580 non-null  category
#  18  Propertycount    13580 non-null  int64
#  19  MeanRoomsSquare  13580 non-null  float64
#  20  AreaRatio        13580 non-null  float64
#  21  MonthSale        13580 non-null  category
#  22  AgeBuilding      13580 non-null  int64
#  23  WeekdaySale      13580 non-null  category
#  24  StreetType       13580 non-null  category
#  25  Weekend          13580 non-null  category
#  26  Quarter          13580 non-null  category
# dtypes: category(11), datetime64[ns](1), float64(8), int64(7)
# memory usage: 1.8 MB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
melb_df.sort_values('Price')
# Out:
#             Suburb  Rooms   Type      Price Method   SellerG       Date  \
# 2652     Footscray      1   unit    85000.0     PI   Burnham 2016-03-09
# 1805         other      4  house   131000.0     PI     other 2017-02-25
# 7303        Albion      1   unit   145000.0     PI    Biggin 2016-05-28
# 1927        Coburg      4  house   145000.0     PI    Jellis 2016-04-06
# 7940      Hawthorn      1   unit   160000.0     VB       HAR 2017-08-04
# ...            ...    ...    ...        ...    ...       ...        ...
# 12557  Middle Park      5  house  6400000.0      S  Marshall 2017-09-09
# 3616           Kew      6  house  6500000.0      S    Jellis 2016-08-13
# 9575      Hawthorn      4  house  7650000.0      S     other 2017-06-17
# 7692    Canterbury      5  house  8000000.0     VB     other 2017-05-13
# 12094        other      3  house  9000000.0     PI     other 2017-07-29
#
#        Distance  Postcode  Bedroom  ...                  Regionname  \
# 2652        6.4      3011        1  ...        Western Metropolitan
# 1805        8.9      3162        4  ...       Southern Metropolitan
# 7303       13.9      3020        2  ...        Western Metropolitan
# 1927        7.8      3058        3  ...       Northern Metropolitan
# 7940        4.6      3122        1  ...       Southern Metropolitan
# ...         ...       ...      ...  ...                         ...
# 12557       3.0      3206        5  ...       Southern Metropolitan
# 3616        5.6      3101        6  ...       Southern Metropolitan
# 9575        5.3      3122        4  ...       Southern Metropolitan
# 7692        9.0      3126        5  ...       Southern Metropolitan
# 12094      18.8      3170        3  ...  South-Eastern Metropolitan
#
#        Propertycount  MeanRoomsSquare  AreaRatio MonthSale  AgeBuilding  \
# 2652            7570        42.000000   1.000000         3            9
# 1805            2379        17.222222  -0.525994         2           97
# 7303            2185        31.500000   0.555556         5           46
# 1927           11204        20.500000  -0.531429         4          106
# 7940           11308        42.000000  -0.437500         8            8
# ...              ...              ...        ...       ...          ...
# 12557           2019        25.666667  -0.284553         9           97
# 3616           10331        20.277778  -0.570335         8          126
# 9575           11308        28.400000  -0.712259         6          154
# 7692            3265        30.953333  -0.634884         5          137
# 12094           7113        16.714286  -0.728223         7           57
#
#        WeekdaySale StreetType  Weekend  Quarter
# 2652             2         St        0        1
# 1805             5         St        1        1
# 7303             5         St        1        2
# 1927             2         Rd        0        2
# 7940             4         St        0        3
# ...            ...        ...      ...      ...
# 12557            5         St        1        3
# 3616             5         St        1        3
# 9575             5         Gr        1        2
# 7692             5         Rd        1        2
# 12094            5         St        1        3
#
# [13580 rows x 27 columns]

# %%
melb_df.sort_values(by='Date', ascending=False)
# Out:
#              Suburb  Rooms   Type      Price Method    SellerG       Date  \
# 11144     Northcote      4  house  1955000.0     SP    McGrath 2017-12-08
# 11217  Surrey Hills      3  house  1775000.0     PI     Jellis 2017-12-08
# 11206      St Kilda      4  house  1600000.0     VB       Gary 2017-12-08
# 11207    Strathmore      7  house  2000000.0     SP     Nelson 2017-12-08
# 11208    Strathmore      4  house  1610000.0      S      other 2017-12-08
# ...             ...    ...    ...        ...    ...        ...        ...
# 1555     Camberwell      4  house  2650000.0      S     Jellis 2016-03-09
# 4510       Oak Park      3  house   892000.0      S     Nelson 2016-03-09
# 4388      Northcote      3  house  1200000.0      S     Nelson 2016-03-09
# 6184   Surrey Hills      3  house  1205000.0      S  Fletchers 2016-01-28
# 6183   Surrey Hills      2   unit   813000.0      S  Fletchers 2016-01-28
#
#        Distance  Postcode  Bedroom  ...             Regionname  Propertycount  \
# 11144       5.3      3070        4  ...  Northern Metropolitan          11364
# 11217      10.2      3127        3  ...  Southern Metropolitan           5457
# 11206       5.0      3182        4  ...  Southern Metropolitan          13240
# 11207       8.2      3041        7  ...   Western Metropolitan           3284
# 11208       8.2      3041        4  ...   Western Metropolitan           3284
# ...         ...       ...      ...  ...                    ...            ...
# 1555        7.8      3124        4  ...  Southern Metropolitan           8920
# 4510       11.5      3046        3  ...  Northern Metropolitan           2651
# 4388        5.5      3070        3  ...  Northern Metropolitan          11364
# 6184       11.2      3127        3  ...  Southern Metropolitan           5457
# 6183       11.2      3127        2  ...  Southern Metropolitan           5457
#
#        MeanRoomsSquare  AreaRatio MonthSale  AgeBuilding  WeekdaySale  \
# 11144        12.600000   0.923664        12           47            4
# 11217        15.750000  -0.721854        12           47            4
# 11206        16.000000  -0.586028        12          107            4
# 11207        20.882353  -0.262721        12           18            4
# 11208        24.909091  -0.517181        12           62            4
# ...                ...        ...       ...          ...          ...
# 1555         18.900000  -0.550535         3          126            2
# 4510         18.000000  -0.714609         3           46            2
# 4388         17.857143  -0.264706         3           96            2
# 6184         18.000000  -0.590909         1           46            3
# 6183         25.200000   0.076923         1           46            3
#
#       StreetType  Weekend  Quarter
# 11144         St        0        4
# 11217         Rd        0        4
# 11206         St        0        4
# 11207         Rd        0        4
# 11208         St        0        4
# ...          ...      ...      ...
# 1555          Rd        0        1
# 4510          St        0        1
# 4388          St        0        1
# 6184          Rd        0        1
# 6183          Rd        0        1
#
# [13580 rows x 27 columns]

# %%
melb_df.sort_values(by=['Distance', 'Price']).loc[::10, ['Distance', 'Price']]
# Out:
#        Distance      Price
# 11428       0.0   387000.0
# 10512       0.7   600000.0
# 5727        1.2   485000.0
# 8671        1.2   595000.0
# 5736        1.2   740000.0
# ...         ...        ...
# 12011      38.0   680000.0
# 10673      38.0   810000.0
# 13429      38.0  1155000.0
# 11102      41.0   650000.0
# 12728      45.9   650000.0
#
# [1358 rows x 2 columns]

# %% [markdown]
# Найдём информацию о таунхаусах (Type), проданных компанией (SellerG) McGrath, у которых коэффициент соотношения площадей здания и участка (AreaRatio) меньше -0.8. Результат отсортируем по дате продажи (Date) в порядке возрастания, а после проведём сортировку по убыванию коэффициента соотношения площадей. Также обновим старые индексы на новые, установив параметр ignore_index на True. Для наглядности результата выберем из таблицы только столбцы Data и AreaRatio:

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-27  -0.953608
# 3 2016-12-11  -0.945946
# 4 2017-08-04  -0.947368
# 5 2017-08-04  -0.970874

# %%
melb_df.sort_values(by='AreaRatio', ascending=True, ignore_index=True).loc[1557, 'BuildingArea']
# Out:
# np.float64(126.0)

# %% [markdown]
# Найдите таунхаусы (Type) с количеством жилых комнат (Rooms) больше 2. Отсортируйте полученную таблицу сначала по возрастанию числа комнат, а затем по убыванию средней площади комнат (MeanRoomsSquare). Индексы таблицы замените на новые. Какая цена будет у объекта в строке 18? Ответ запишите в виде целого числа.

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
melb_df[mask1 & mask2].sort_values(['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).loc[18, 'Price']
# Out:
# np.float64(1300000.0)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# /tmp/ipython-input-152-2774055988.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
#            Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# Type
# house        7259.025505        18.996731  -0.490031    55.669700
# townhouse    7094.459605        18.569847  -0.094916    26.690305
# unit         8199.280080        21.068242   0.319883    39.703016

# %%
melb_df.groupby('Type')['Price'].mean()
# Out:
# /tmp/ipython-input-153-2328732824.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %% [markdown]
# Для этого найдём минимальное значение расстояния от центра города до объекта в зависимости от его региона. Результат отсортируем по убыванию расстояния

# %%
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Out:
# /tmp/ipython-input-154-3783769093.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %%
melb_df.groupby('MonthSale')['Price'].agg(['count', 'mean', 'max']).sort_values(by='count', ascending=False)
# Out:
# /tmp/ipython-input-155-3775246841.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg(['count', 'mean', 'max']).sort_values(by='count', ascending=False)
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg('describe')
# Out:
# /tmp/ipython-input-156-701566850.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# 12          725.0  1.144737e+06  706549.007161  250000.0  667500.0   938000.0
#
#                  75%        max
# MonthSale
# 1          1111250.0  5200000.0
# 2          1478000.0  4735000.0
# 3          1400000.0  5600000.0
# 4          1298750.0  5500000.0
# 5          1371250.0  8000000.0
# 6          1325000.0  7650000.0
# 7          1150000.0  9000000.0
# 8          1310000.0  6500000.0
# 9          1360000.0  6400000.0
# 10         1416500.0  6250000.0
# 11         1399125.0  5050000.0
# 12         1412000.0  5700000.0

# %%
melb_df.groupby('Regionname')['SellerG'].agg(
    		['nunique', set]
)
# Out:
# /tmp/ipython-input-157-1626580071.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Harcourts, Miles, Woodards, HAR, Ray, RW, C21...
# Eastern Victoria            {Harcourts, Eview, hockingstuart, McGrath, O'B...
# Northern Metropolitan       {Harcourts, Miles, Woodards, Burnham, HAR, Ray...
# Northern Victoria           {YPA, hockingstuart, McGrath, HAR, other, Barr...
# South-Eastern Metropolitan  {Harcourts, O'Brien, Woodards, HAR, Ray, C21, ...
# Southern Metropolitan       {Harcourts, O'Brien, Woodards, HAR, Williams, ...
# Western Metropolitan        {Harcourts, O'Brien, Woodards, Burnham, Willia...
# Western Victoria                 {YPA, hockingstuart, HAR, Ray, Raine, other}

# %%
melb_df.groupby('Rooms')['Price'].mean()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 7     1.920700e+06
# 8     1.602750e+06
# 10    9.000000e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std()
# Out:
# /tmp/ipython-input-159-1377463709.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['Lattitude'].std()
# Regionname
# Eastern Metropolitan          0.047890
# Eastern Victoria              0.147067
# Northern Metropolitan         0.049639
# Northern Victoria             0.084455
# South-Eastern Metropolitan    0.073411
# Southern Metropolitan         0.043080
# Western Metropolitan          0.051251
# Western Victoria              0.011579
# Name: Lattitude, dtype: float64

# %% [markdown]
# Какая риелторская компания (SellerG) имеет наименьшую общую выручку за период с 1 мая по 1 сентября (включительно) 2017 года?
# Для ответа на этот вопрос рассчитайте сумму продаж (Price) каждой компании в заданный период.
# Не забудьте перевести даты в формат datetime.

# %%
data1 = pd.to_datetime('2017.05.01')
data2 = pd.to_datetime('2017.07.01')
mask = (data1 < melb_df['Date']) & (data2 > melb_df['Date'])
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values()
# Out:
# /tmp/ipython-input-160-577734721.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df[mask].groupby('SellerG')['Price'].sum().sort_values()
# SellerG
# LITTLE              970000.0
# Thomson            3085000.0
# Burnham            3707500.0
# Cayzer             3804000.0
# Moonee             4111000.0
# Bells              5546000.0
# Buckingham         5996000.0
# Alexkarbon         6022000.0
# McDonald           6082000.0
# Nick               6310000.0
# Eview              6479000.0
# RW                 6565000.0
# O'Brien            7335000.0
# HAR                7380000.0
# Philip             7803000.0
# C21                9156500.0
# Love               9991000.0
# Williams          10462000.0
# Douglas           10720000.0
# Chisholm          11725000.0
# Purplebricks      12428000.0
# Rendina           12835276.0
# Raine             14369000.0
# Collins           14772000.0
# Village           16327500.0
# Stockdale         16733500.0
# YPA               16986500.0
# Jas               17675600.0
# Sweeney           18743500.0
# Miles             21428500.0
# Gary              23631000.0
# Hodges            26830000.0
# Harcourts         27685500.0
# Brad              30759000.0
# McGrath           34945000.0
# Kay               35054500.0
# RT                37406000.0
# Fletchers         41354500.0
# Greg              46110000.0
# Woodards          49081500.0
# Noel              52124500.0
# Biggin            58418000.0
# Ray              107022748.0
# Buxton           124490500.0
# Barry            128890700.0
# hockingstuart    129538500.0
# Marshall         168412000.0
# other            178526182.0
# Nelson           213282500.0
# Jellis           245175757.0
# Name: Price, dtype: float64

# %%
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# /tmp/ipython-input-162-442157687.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
melb_df.pivot_table(
    values='Price',
    index='Rooms',
    columns='Type',
    fill_value=0
).round()
# Out:
# /tmp/ipython-input-163-3628189379.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
    values='Price',
    index='Regionname',
    columns='Weekend',
    aggfunc='count'
)
# Out:
# /tmp/ipython-input-164-2049665855.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
# /tmp/ipython-input-165-186795090.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# /tmp/ipython-input-165-186795090.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62.0   507.883406  244.560669
# Western Victoria            599.5       0.0    0.0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# South-Eastern Metropolitan  357.864865
# Southern Metropolitan       466.380245
# Western Metropolitan        557.637232
# Western Victoria              0.000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
pivot
# Out:
# /tmp/ipython-input-166-112478162.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(
# /tmp/ipython-input-166-112478162.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = melb_df.pivot_table(
#                            median                          mean              \
# Type                        house townhouse   unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203.0   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230.0  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0.0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0.0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199.0   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0.0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62.0   507.883406  244.560669
# Western Victoria            599.5       0.0    0.0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# South-Eastern Metropolitan  357.864865
# Southern Metropolitan       466.380245
# Western Metropolitan        557.637232
# Western Victoria              0.000000

# %%
display(pivot['mean']['unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: unit, dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                        mean              \
# Type                   house townhouse  unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0   0.0  569.643881  278.858824
# Western Metropolitan   531.0     198.0  62.0  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %% [markdown]
# Составьте сводную таблицу, которая показывает зависимость медианной площади (BuildingArea) здания от типа объекта недвижимости (Type) и количества жилых комнат в доме (Rooms). Для какой комбинации признаков площадь здания наибольшая?

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type',
    aggfunc='median'
)
# Out:
# /tmp/ipython-input-169-2858439082.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   melb_df.pivot_table(
# Type   house  townhouse   unit
# Rooms
# 1      126.0       88.0   69.5
# 2      126.0      114.0  110.0
# 3      126.0      126.0  126.0
# 4      141.0      159.5  126.0
# 5      177.0      152.0    NaN
# 6      126.0        NaN  171.0
# 7      216.5        NaN    NaN
# 8      126.0        NaN  126.0
# 10     126.0        NaN    NaN

# %% [markdown]
# Составьте сводную таблицу, которая показывает зависимость медианной цены объекта недвижимости (Price) от риелторского агентства (SellerG) и типа здания (Type).
# Во вновь созданной таблице найдите агентство, у которого медианная цена для зданий типа unit максимальна. В качестве ответа запишите название этого агентства.

# %%
pivot_1 = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type',
    aggfunc='median'
)
# Out:
# /tmp/ipython-input-170-4011985194.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_1 = melb_df.pivot_table(

# %%
pivot_1
# Out:
# Type               house  townhouse      unit
# SellerG
# Alexkarbon     1036250.0   935000.0  560000.0
# Barry           830000.0   727500.0  502000.0
# Bells           692500.0   430500.0  457500.0
# Biggin         1151750.0   675000.0  548000.0
# Brad            875000.0   700000.0  465000.0
# Buckingham      830000.0   820000.0  553000.0
# Burnham         922500.0        NaN  305000.0
# Buxton         1323750.0  1030000.0  670000.0
# C21             836500.0   768750.0  625500.0
# Cayzer         1505000.0  1450000.0  707500.0
# Chisholm       1520000.0   950000.0  640000.0
# Collins        1566500.0   930000.0  592000.0
# Douglas         684000.0   500000.0  494500.0
# Eview           760000.0   597500.0  602000.0
# Fletchers      1390000.0  1238000.0  653000.0
# Gary           1370000.0   993500.0  550000.0
# Greg           1330000.0   900000.0  547500.0
# HAR             695000.0        NaN  518000.0
# Harcourts       740000.0   653750.0  500000.0
# Hodges         1500000.0  1105000.0  605500.0
# Jas             935000.0   699000.0  455000.0
# Jellis         1505000.0  1052000.0  591750.0
# Kay            2220000.0  1365000.0  695000.0
# LITTLE          970000.0   800000.0  447000.0
# Love            780000.0   846000.0  440000.0
# Marshall       1975000.0  1408500.0  715000.0
# McDonald       1242500.0        NaN  502500.0
# McGrath        1250000.0   810000.0  542500.0
# Miles          1090000.0   721500.0  555000.0
# Moonee          806000.0   715000.0  622000.0
# Nelson         1055000.0   730000.0  530000.0
# Nick           2025000.0   780000.0  900000.0
# Noel           1400500.0   990000.0  693250.0
# O'Brien         737504.0   430000.0  618500.0
# Philip         1035000.0   701000.0  636000.0
# Purplebricks    810000.0   927500.0  582500.0
# RT             1640000.0  1400000.0  630000.0
# RW              870000.0   630500.0  625500.0
# Raine           745000.0   608000.0  447500.0
# Ray             900000.0   650000.0  497500.0
# Rendina        1190000.0   750000.0  459000.0
# Stockdale       715500.0   550000.0  410000.0
# Sweeney         850000.0   728000.0  381000.0
# Thomson        1177000.0   500000.0  495000.0
# Village         973500.0   727500.0  420000.0
# Williams       1161000.0   735000.0  577000.0
# Woodards       1261000.0   865500.0  600000.0
# YPA             596250.0   498500.0  443500.0
# hockingstuart  1055000.0   935000.0  566000.0
# other           901000.0   840500.0  535000.0

# %%
max_price = pivot_1['unit'].max()
pivot_1[pivot_1['unit'] == max_price]
# Out:
# Type         house  townhouse      unit
# SellerG
# Nick     2025000.0   780000.0  900000.0

# %%
ratings1 = pd.read_csv('ratings1.csv')
ratings2 = pd.read_csv('ratings2.csv')
movies = pd.read_csv('movies.csv')
dates = pd.read_csv('dates.csv')

# %%
ratings1
# Out:
#        userId  movieId  rating
# 0           1        1     4.0
# 1           1        3     4.0
# 2           1        6     4.0
# 3           1       47     5.0
# 4           1       50     5.0
# ...       ...      ...     ...
# 39996     274     5582     2.5
# 39997     274     5585     3.5
# 39998     274     5588     3.5
# 39999     274     5618     4.0
# 40000     274     5621     2.0
#
# [40001 rows x 3 columns]

# %%
movies['title'].nunique()
# Out:
# 9737

# %%
ratings1['userId'].nunique()
# Out:
# 274

# %%
dates['date'] = pd.to_datetime(dates['date'])
dates['Year'] = dates['date'].dt.year
dates['Year'].value_counts()
# Out:
# Year
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ratings = pd.concat([ratings1, ratings2], ignore_index=True)
display(ratings)
# Out:
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100832     610   166534     4.0
# 100833     610   168248     5.0
# 100834     610   168250     5.0
# 100835     610   168252     5.0
# 100836     610   170875     3.0
#
# [100837 rows x 3 columns]

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
print('Число строк в таблице dates: ', dates.shape[0])
print(ratings.shape[0] == dates.shape[0])

# Число строк в таблице ratings: 100837
# Число строк в таблице dates: 100836
# False
# Out:
# Число строк в таблице ratings:  100837
# Число строк в таблице dates:  100836
# False

# %%
display(ratings1.tail(1))
display(ratings2.head(1))
# Out:
#        userId  movieId  rating
# 40000     274     5621     2.0
#    userId  movieId  rating
# 0     274     5621     2.0

# %%
ratings = ratings.drop_duplicates(ignore_index=True)

# %%
print('Число строк в таблице ratings: ', ratings.shape[0])
# Число строк в таблице ratings: 100836
# Out:
# Число строк в таблице ratings:  100836

# %%
ratings_dates = pd.concat([ratings, dates], axis=1)
ratings_dates
# Out:
#         userId  movieId  rating                date  Year
# 0            1        1     4.0 2000-07-30 18:45:03  2000
# 1            1        3     4.0 2000-07-30 18:20:47  2000
# 2            1        6     4.0 2000-07-30 18:37:04  2000
# 3            1       47     5.0 2000-07-30 19:03:35  2000
# 4            1       50     5.0 2000-07-30 18:48:51  2000
# ...        ...      ...     ...                 ...   ...
# 100831     610   166534     4.0 2017-05-03 21:53:22  2017
# 100832     610   168248     5.0 2017-05-03 22:21:31  2017
# 100833     610   168250     5.0 2017-05-08 19:50:47  2017
# 100834     610   168252     5.0 2017-05-03 21:19:12  2017
# 100835     610   170875     3.0 2017-05-03 21:20:15  2017
#
# [100836 rows x 5 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
joined_false = ratings_dates.join(
    movies,
    rsuffix='_right',
    how='left'
)
display(joined_false)
# Out:
#         userId  movieId  rating                date  Year  movieId_right  \
# 0            1        1     4.0 2000-07-30 18:45:03  2000            1.0
# 1            1        3     4.0 2000-07-30 18:20:47  2000            2.0
# 2            1        6     4.0 2000-07-30 18:37:04  2000            3.0
# 3            1       47     5.0 2000-07-30 19:03:35  2000            4.0
# 4            1       50     5.0 2000-07-30 18:48:51  2000            5.0
# ...        ...      ...     ...                 ...   ...            ...
# 100831     610   166534     4.0 2017-05-03 21:53:22  2017            NaN
# 100832     610   168248     5.0 2017-05-03 22:21:31  2017            NaN
# 100833     610   168250     5.0 2017-05-08 19:50:47  2017            NaN
# 100834     610   168252     5.0 2017-05-03 21:19:12  2017            NaN
# 100835     610   170875     3.0 2017-05-03 21:20:15  2017            NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                           Jumanji (1995)
# 2                  Grumpier Old Men (1995)
# 3                 Waiting to Exhale (1995)
# 4       Father of the Bride Part II (1995)
# ...                                    ...
# 100831                                 NaN
# 100832                                 NaN
# 100833                                 NaN
# 100834                                 NaN
# 100835                                 NaN
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1                        Adventure|Children|Fantasy
# 2                                    Comedy|Romance
# 3                              Comedy|Drama|Romance
# 4                                            Comedy
# ...                                             ...
# 100831                                          NaN
# 100832                                          NaN
# 100833                                          NaN
# 100834                                          NaN
# 100835                                          NaN
#
# [100836 rows x 8 columns]

# %%
joined = ratings_dates.join(
    movies.set_index('movieId'),
    on='movieId',
    how='left'
)
display(joined.head())
# Out:
#    userId  movieId  rating                date  Year  \
# 0       1        1     4.0 2000-07-30 18:45:03  2000
# 1       1        3     4.0 2000-07-30 18:20:47  2000
# 2       1        6     4.0 2000-07-30 18:37:04  2000
# 3       1       47     5.0 2000-07-30 19:03:35  2000
# 4       1       50     5.0 2000-07-30 18:48:51  2000
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
merged = ratings_dates.merge(
    movies,
    on='movieId',
    how='left'
)
display(merged.head())
# Out:
#    userId  movieId  rating                date  Year  \
# 0       1        1     4.0 2000-07-30 18:45:03  2000
# 1       1        3     4.0 2000-07-30 18:20:47  2000
# 2       1        6     4.0 2000-07-30 18:37:04  2000
# 3       1       47     5.0 2000-07-30 19:03:35  2000
# 4       1       50     5.0 2000-07-30 18:48:51  2000
#
#                          title                                       genres
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller

# %%
print('Число строк в таблице ratings_dates: ', ratings_dates.shape[0])
print('Число строк в таблице merged: ', merged.shape[0])
print(ratings_dates.shape[0] == merged.shape[0])

# Число строк в таблице ratings_dates: 100836
# Число строк в таблице merged: 100836
# True
# Out:
# Число строк в таблице ratings_dates:  100836
# Число строк в таблице merged:  100836
# True

# %%
merged2 = ratings_dates.merge(
    movies,
    on='movieId',
    how='outer'
)
print('Число строк в таблице merged2: ', merged2.shape[0])
display(merged2.tail())

# Число строк в таблице merged: 100854
# Out:
# Число строк в таблице merged2:  100854
#         userId  movieId  rating                date    Year  \
# 100849   184.0   193581     4.0 2018-09-16 14:44:42  2018.0
# 100850   184.0   193583     3.5 2018-09-16 14:52:25  2018.0
# 100851   184.0   193585     3.5 2018-09-16 14:56:45  2018.0
# 100852   184.0   193587     3.5 2018-09-16 15:00:21  2018.0
# 100853   331.0   193609     4.0 2018-09-17 04:13:26  2018.0
#
#                                             title  \
# 100849  Black Butler: Book of the Atlantic (2017)
# 100850               No Game No Life: Zero (2017)
# 100851                               Flint (2017)
# 100852        Bungo Stray Dogs: Dead Apple (2018)
# 100853        Andrew Dice Clay: Dice Rules (1991)
#
#                                  genres
# 100849  Action|Animation|Comedy|Fantasy
# 100850         Animation|Comedy|Fantasy
# 100851                            Drama
# 100852                 Action|Animation
# 100853                           Comedy

# %%
merge_ratings = ratings1.merge(ratings2, how='outer')
print('Число строк в таблице merge_ratings: ', merge_ratings.shape[0])
display(merge_ratings)
# Число строк в таблице merge_ratings: 100836
# Out:
# Число строк в таблице merge_ratings:  100836
#         userId  movieId  rating
# 0            1        1     4.0
# 1            1        3     4.0
# 2            1        6     4.0
# 3            1       47     5.0
# 4            1       50     5.0
# ...        ...      ...     ...
# 100831     610   166534     4.0
# 100832     610   168248     5.0
# 100833     610   168250     5.0
# 100834     610   168252     5.0
# 100835     610   170875     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
