# %%
import math
x = int(input())

import math

res = math.floor(500 / (0.9*x))

# %%
print(res)
# Out:
# 15

# %%
a = int("-6")
print(a)
# Out:
# -6

# %%
a = input()
a.replace(' ', '\’', 1)
print(a.replace(' ', '\'', 1).replace(' ', '\"'))
# Out:
# fds'grfd"hgfd"grfd

# %%
a = [1, 3, 5, 2]
d = a
print(id(a), id(d))
# Out:
# 2560184456576 2560184456576

# %%
a[1] = 675849
print(a, d)
# Out:
# [1, 675849, 5, 2] [1, 675849, 5, 2]

# %%
a = list(input())
a.remove('+')
a[0] = '8'
a.remove('-')
a.remove('-')
print(''.join(a))
# Out:
# 8(912)1234567
